# %%
import pandas as pd

# %%
poverty_data = pd.read_csv('poverty_data.csv', encoding= 'unicode_escape')
poverty_data
# Out:
#                Unnamed: 0      Unnamed: 1    Unnamed: 2                  \
# 0                     NaN  3-year average           NaN  2-year average
# 1                   State      2016-20181           NaN       2015-2016
# 2                     NaN             NaN     Margin of             NaN
# 3                     NaN      Percentage  error2 (+/-)      Percentage
# 4        United States
#
# .            12.3           0.2            13.1
# 5                 Alabama              16           1.5            16.3
# 6                  Alaska            12.2           1.8            10.9
# 7                 Arizona            14.4           1.6            16.6
# 8              Arkansas              15.5           1.1            16.1
# 9              California            12.5           0.5            13.9
# 10               Colorado             8.9           0.9             9.2
# 11            Connecticut             9.9           1.3             9.5
# ...

# %%
poverty_data.columns =["State", "2016-18 Average %", "2016-18 Error Margin", "2015-16 Average %", "2015-16 Error Margin", 
             "2017-18 Average %","2017-18 Error Margin", "Change in % 2015 to 2017",
                                "% Change Error Margin"] 
poverty_data.head()
# Out:
#                    State 2016-18 Average % 2016-18 Error Margin  \
# 0                    NaN    3-year average                  NaN
# 1                  State        2016-20181                  NaN
# 2                    NaN               NaN            Margin of
# 3                    NaN        Percentage         error2 (+/-)
# 4       United States
#
# .              12.3                  0.2
#
#   2015-16 Average % 2015-16 Error Margin 2017-18 Average %  \
# 0    2-year average       2-year average               NaN
# 1         2015-2016                  NaN        2017-20181
# 2               NaN            Margin of               NaN
# 3        Percentage         error2 (+/-)        Percentage
# 4              13.1                  0.2                12
#
#   2017-18 Error Margin Change in % 2015 to 2017 % Change Error Margin
# 0                  NaN  (2017-2018 average less                   NaN
# 1                  NaN      2015-2016 average)3                   NaN
# ...

# %%
new_data=poverty_data.drop([0,1,2,3])
new_data
# Out:
#                     State 2016-18 Average % 2016-18 Error Margin  \
# 4        United States
#
# .              12.3                  0.2
# 5                 Alabama                16                  1.5
# 6                  Alaska              12.2                  1.8
# 7                 Arizona              14.4                  1.6
# 8              Arkansas                15.5                  1.1
# 9              California              12.5                  0.5
# 10               Colorado               8.9                  0.9
# 11            Connecticut               9.9                  1.3
# 12               Delaware               9.6                  1.1
# 13   District of Columbia              14.9                  1.1
# 14                Florida              13.6                  0.9
# 15                Georgia              14.7                  1.1
# 16                 Hawaii               9.5                  1.2
# ...

# %%
new_data.reset_index(drop=True)
# Out:
#                     State 2016-18 Average % 2016-18 Error Margin  \
# 0        United States
#
# .              12.3                  0.2
# 1                 Alabama                16                  1.5
# 2                  Alaska              12.2                  1.8
# 3                 Arizona              14.4                  1.6
# 4              Arkansas                15.5                  1.1
# 5              California              12.5                  0.5
# 6                Colorado               8.9                  0.9
# 7             Connecticut               9.9                  1.3
# 8                Delaware               9.6                  1.1
# 9    District of Columbia              14.9                  1.1
# 10                Florida              13.6                  0.9
# 11                Georgia              14.7                  1.1
# 12                 Hawaii               9.5                  1.2
# ...

# %%
new_data.head()
# Out:
#                    State 2016-18 Average % 2016-18 Error Margin  \
# 4       United States
#
# .              12.3                  0.2
# 5                Alabama                16                  1.5
# 6                 Alaska              12.2                  1.8
# 7                Arizona              14.4                  1.6
# 8             Arkansas                15.5                  1.1
#
#   2015-16 Average % 2015-16 Error Margin 2017-18 Average %  \
# 4              13.1                  0.2                12
# 5              16.3                  1.9              15.6
# 6              10.9                  1.6              12.6
# 7              16.6                  1.5              13.2
# 8              16.1                  1.1              15.4
#
#   2017-18 Error Margin Change in % 2015 to 2017 % Change Error Margin
# 4                  0.2                    *-1.1                   0.3
# 5                  1.6                     -0.6                   1.9
# ...
